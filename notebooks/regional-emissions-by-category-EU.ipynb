# %%
definition = [
        {'code': 'CRF1A1_CRF1B',  # vnitřní graf, políčko 1                 ENERGETIKA
         'label': 'Energetika',
         'sum': ['CRF1A1', 'CRF1B'],
         'color': '#ff4245',
         'breakdown': [
             {'code': 'CRF1B',  # vnější graf políčko 1.1
              'label': 'Úniky při těžbě paliv',
              'color': '#c22628',
              'sum': ['CRF1B']},
             {'code': 'CRF1A1C',  # vnější graf políčko 1.2
              'label': 'Výroba a úprava paliv',
              'color': '#c22628',
              'sum': ['CRF1A1C']},
             {'code': 'CRF1A1A',  # vnější graf políčko 1.3 
              'label': 'Výroba elektřiny a tepla',
              'color': '#d70205',
              'sum': ['CRF1A1A']},
             {'code': 'CRF1A1B',  # vnější graf políčko 1.4
              'label': 'Zpracování ropy',
              'color': '#c22628',
              'sum': ['CRF1A1B']}]},
        {'code': 'CRF1A3_CRF1D1A',  # vnitřní graf, políčko 2         DOPRAVA
         'label': 'Doprava (včetně letecké)',
         'sum': ['CRF1A3', 'CRF1D1A'],
         'color': '#a10014',
         'breakdown': [
             {'code': 'CRF1A3B1',  # vnější graf políčko 2.1
              'label': 'Automobilová doprava',
              'color': '#73000c',
              'sum': ['CRF1A3B1']},
             {'code': 'CRF1A3B2_CRF1A3B3',  # vnější graf políčko 2.2
              'label': 'Nákladní a autobusová doprava',
              'color': '#8f0a19',
              'sum': ['CRF1A3B2', 'CRF1A3B3']},
             {'code': 'CRF1D1A_CRF1A3A',  # vnější graf políčko 2.3
              'label': 'Letecká doprava',
              'color': '#94545c',
              'sum': ['CRF1D1A', 'CRF1A3A']},
             {'code': 'CRF1A3_dif',  # vnější graf políčko 2.4 - rozdíl
              'label': 'Jiná doprava',
              'color': '#c7858c',
              'reminder': True}]},
        {'code': 'CRF1A4',  # vnitřní graf, políčko 3                 SPALOVÁNÍ V DOM, INST A ZEMĚĎ
         'label': 'Spalování v domácnostech, institucích a zemědělství',
         'sum': ['CRF1A4'],
         'color': '#00007f'},
        {'code': 'CRF1A2',  # vnitřní graf, políčko 4                 SPALOVÁNÍ V PRŮMYSLU
         'label': 'Spalování v průmyslu',
         'sum': ['CRF1A2'],
         'color': '#3891dc'},    
        {'code': 'CRF3',  # vnitřní graf, políčko 5                   ZEMĚDĚLSTVÍ
         'label': 'Zemědělství',
         'sum': ['CRF3'],
         'color': '#1ecfbd'},    
        {'code': 'CRF2',  # vnitřní graf, políčko 6                 PRŮMYSLOVÉ PROCESY
         'label': 'Průmyslové procesy (výroba cementu, oceli...)',
         'sum': ['CRF2'],
         'color': '#7363bd'},
        {'code': 'CRF5',  # vnitřní graf, políčko 7                   ODPADOVÉ HOSPODÁŘSTVÍ
         'label': 'Odpadové hospodářství',
         'sum': ['CRF5'],
         'color': '#029485'},
        {'code': 'TOTAL_DIF',  # vnitřní graf, políčko 8                   JINÉ
         'label': 'Jiné',
         'color': '#f8c551',
         'reminder': True}
    ]

# %%
from regional_emissions_by_category_lib import create_plot

# %%
# 'EU28' for EU until 2019
# 'EU27_2020' for EU since 2020 (without UK)
STATE = 'EU28'
YEAR = 2019
powerplants = [] # has to be an empty list
create_plot(STATE, YEAR, definition, powerplants)
