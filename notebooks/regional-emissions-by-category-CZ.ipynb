# %%
definition = [
        {'code': 'CRF1A1',  # vnitřní graf, políčko 1                 ENERGETIKA
         'label': 'Energetika',
         'sum': ['CRF1A1'],
         'color': '#ff4245',
         'breakdown': [
             {'code': 'CRF1A1C_CRF1A1B',  # vnější graf políčko 1.1
              'label': 'Výroba a úprava paliv',
              'color': '#c22628',
              'sum': ['CRF1A1C', 'CRF1A1B']},
             {'code': 'CRF1B',  # vnější graf políčko 1.1
              'label': 'Úniky při těžbě paliv',
              'color': '#c22628',
              'sum': ['CRF1B']},
             {'code': 'CRF1A2_dif_X',  # vnější graf políčko 1.2 - rozdíl
              'label': 'Teplárny',
              'color': '#d70205',
              'reminder': True},
             {'code': 'CZ-0204-05',  # vnější graf políčko 1.3
              'label': 'Elektrárna Počerady',
              'color': '#c22628',
              'sum': ['CZ-0204-05'],
              'allowances': True},
             {'code': 'CZ-0206-05_CZ-0207-05',  # vnější graf políčko 1.4
              'label': 'Elektrárna Prunéřov',
              'color': '#c23d3f',
              'sum': ['CZ-0206-05', 'CZ-0207-05'],
              'allowances': True},
             {'code': 'CZ-0209-05',  # vnější graf políčko 1.5
              'label': 'Elektrárna Tušimice', 
              'color': '#e11114',
              'sum': ['CZ-0209-05'],
              'allowances': True},
             {'code': 'CZ-0200-05',  # vnější graf políčko 1.6
              'label': 'Elektrárna Chvaletice',
              'color': '#f01e23',
              'sum': ['CZ-0200-05'],
              'allowances': True},
             {'code': 'CZ-0092-05_CZ-0202-05_CZ-0203-05',  # vnější graf políčko 1.7
              'label': 'Elektrárna Mělník',
              'color': '#ff2e30',
              'sum': ['CZ-0092-05', 'CZ-0202-05', 'CZ-0203-05'],
              'allowances': True},
             {'code': 'CZ-0148-05_CZ-0417-06',  # vnější graf políčko 1.8
              'label': 'Elektrárna Kladno',
              'color': '#ff4245',
              'sum': ['CZ-0148-05', 'CZ-0417-06'],
              'allowances': True},
             {'code': 'CZ-0198-05',  # vnější graf políčko 1.9
              'label': 'Elektrárna Dětmarovice',
              'color': '#ff6e70',
              'sum': ['CZ-0198-05'],
              'allowances': True},
             {'code': 'CRF1A2_dif_Y',  # vnější graf políčko 1.10
              'label': 'Ostatní elektrárny',
              'color': '#ff6e70',                                                                            
              'sum': ['CZ-0080-05', 'CZ-0208-05', 'CZ-0201-05', 'CZ-0447-11', 'CZ-0317-05', 'CZ-0205-05'],
              'allowances': True}]},
        {'code': 'CRF1A3_CRF1D1A',  # vnitřní graf, políčko 2         DOPRAVA
         'label': 'Doprava (včetně letecké)',
         'sum': ['CRF1A3', 'CRF1D1A'],
         'color': '#a10014',
         'breakdown': [
             {'code': 'CRF1A3B1',  # vnější graf políčko 2.1
              'label': 'Osobní automobilová doprava',
              'color': '#73000c',
              'sum': ['CRF1A3B1']},
             {'code': 'CRF1A3B2_CRF1A3B3',  # vnější graf políčko 2.2
              'label': 'Nákladní a autobusová doprava',
              'color': '#8f0a19',
              'sum': ['CRF1A3B2', 'CRF1A3B3']},
             {'code': 'CRF1D1A_CRF1A3A',  # vnější graf políčko 2.3
              'label': 'Letecká doprava',
              'color': '#94545c',
              'sum': ['CRF1D1A', 'CRF1A3A']},
             {'code': 'CRF1A3_dif',  # vnější graf políčko 2.4 - rozdíl
              'label': 'Jiná doprava',
              'color': '#c7858c',
              'reminder': True}]},
        {'code': 'CRF2',  # vnitřní graf, políčko 3                 PRŮMYSLOVÉ PROCESY
         'label': 'Průmyslové procesy (výroba cementu, oceli...)',
         'sum': ['CRF2'],
         'color': '#7363bd',
         'breakdown': [
             {'code': 'CRF2C',  # vnější graf políčko 3.1
              'label': 'Zpracování oceli a kovů',
              'color': '#6e3394',
              'sum': ['CRF2C']},
             {'code': 'CRF2A',  # vnější graf políčko 3.2
              'label': 'Minerální produkce (cement, vápno...)',
              'color': '#7a45a1',
              'sum': ['CRF2A']},
             {'code': 'CRF2B',  # vnější graf políčko 3.3
              'label': 'Chemický průmysl',
              'color': '#7363bd',
              'sum': ['CRF2B']},
             {'code': 'CRF2_dif',  # vnější graf políčko 3.3 - rozdíl
              'label': 'Další průmyslové procesy',
              'color': '#8575de',
              'reminder': True}]},
        {'code': 'CRF1A2',  # vnitřní graf, políčko 4                 SPALOVÁNÍ V PRŮMYSLU
         'label': 'Spalování v průmyslu',
         'sum': ['CRF1A2'],
         'color': '#3891dc',
         'breakdown': [
             {'code': 'CRF1A2A_CRF1A2B',  # vnější graf políčko 4.1
              'label': 'Spalování při zpracování oceli a kovů',
              'color': '#307ab8',
              'sum': ['CRF1A2A', 'CRF1A2B']},
             {'code': 'CRF1A2_dil',  # vnější graf políčko 4.2 - rozdíl
              'label': 'Další spalování v průmyslu',
              'color': '#3891dc',
              'reminder': True}]},
        {'code': 'CRF1A4',  # vnitřní graf, políčko 5                 SPALOVÁNÍ V DOM, INST A ZEMĚĎ
         'label': 'Spalování v domácnostech, institucích a zemědělství',
         'sum': ['CRF1A4'],
         'color': '#00007f'},
        {'code': 'CRF3',  # vnitřní graf, políčko 6                   ZEMĚDĚLSTVÍ
         'label': 'Zemědělství',
         'sum': ['CRF3'],
         'color': '#1ecfbd'},
        {'code': 'CRF5',  # vnitřní graf, políčko 7                   ODPADOVÉ HOSPODÁŘSTVÍ
         'label': 'Odpadové hospodářství',
         'sum': ['CRF5'],
         'color': '#029485'},
        {'code': 'TOTAL_DIF',  # vnitřní graf, políčko 8               JINÉ
         'label': 'Jiné',
         'color': '#f8c551',
         'reminder': True}
    ]

# %%
from regional_emissions_by_category_lib import create_plot

# %%
STATE = 'CZ'
YEAR = 2019

create_plot(STATE, YEAR, definition)
